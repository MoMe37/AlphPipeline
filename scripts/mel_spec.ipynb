# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
samples, sample_rate = librosa.load("../../AlphData/fadg0/audio/sa1.wav", sr=None)

# %%
print("sample : ", samples)
print("len : ", len(samples))
print("sample rate : ", sample_rate)
# Out:
# sample :  [ 0.003479    0.00061035 -0.00064087 ... -0.02127075 -0.01885986
#  -0.02020264]
# len :  152320
# sample rate :  32000

# %%
sample = []
for i in range(119):
    sample.append(samples[int(i*(len(samples)/119)):int((i+1)*(len(samples)/119))])
len(sample[0])
# Out:
# 1280

# %%
mel_spec = []
for i in range(119):
    mel_spec.append(librosa.feature.melspectrogram(y=sample[i], sr=sample_rate, n_fft = 2048, hop_length = 15, win_length=30))
librosa.display.specshow(mel_spec[69], sr=sample_rate, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
# Out:
# C:\Users\Enzo.Magal\AppData\Local\Programs\Python\Python39\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1280
#   warnings.warn(

# %%
len(mel_spec[0][0])
# Out:
# 86

# %%
mel_spec = []
for i in range(119):
    spectrogram = librosa.stft(sample[i], n_fft = 1024, hop_length = 41, win_length=82)
    sgram_mag, _ = librosa.magphase(spectrogram)
    mel_scale_sgram = librosa.feature.melspectrogram(S=sgram_mag, sr= sample_rate)
    mel_spec.append(librosa.amplitude_to_db(mel_scale_sgram, ref=np.min))
librosa.display.specshow(mel_spec[118], sr=sample_rate, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')

# %%
len(mel_spec[0][0])
# Out:
# 32
